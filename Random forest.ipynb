# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("data202.csv")

# %%
print(df.columns)
# Out:
# Index(['degree', 'water', 'plot', 'mitti', 'N', 'P', 'K', 'ph', 'plant',
#        'pro'],
#       dtype='object')

# %%
dum2 = pd.get_dummies(df['plot'])
dum3 = pd.get_dummies(df['mitti'])
dum4 = pd.get_dummies(df['plant'])

# %%
merg = pd.concat([df, dum2, dum3, dum4], axis='columns')
final = merg.drop(['plot', 'mitti', 'plant'], axis='columns')

# %%
final.fillna(final.mean(), inplace=True)

# %%
final.replace([np.inf, -np.inf], np.finfo(np.float32).max, inplace=True)

# %%
X = df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(final.drop('pro', axis='columns'), final['pro'], test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (1407, 186)

# %%
y_train.shape
# Out:
# (1407,)

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred =rf.predict(X_test)

# %%
y_pred
# Out:
# array([7.948550e+02, 2.449700e+03, 3.197435e+03, 3.797947e+03,
#        4.375960e+02, 3.910950e+03, 5.184680e+02, 2.784990e+03,
#        8.307000e+03, 2.995950e+03, 1.192194e+03, 3.325000e+03,
#        5.168090e+02, 3.057520e+03, 3.130290e+03, 1.320366e+03,
#        8.747000e+03, 4.085550e+03, 9.087810e+02, 2.088835e+03,
#        1.193000e+03, 6.250000e+02, 6.628000e+01, 3.874240e+02,
#        1.034858e+03, 2.091600e+03, 3.745920e+02, 5.803300e+03,
#        3.422918e+03, 1.197751e+03, 1.604021e+03, 4.911790e+03,
#        3.550100e+03, 4.935730e+02, 4.191200e+03, 2.582884e+03,
#        8.055000e+02, 2.243000e+03, 2.596820e+03, 3.861849e+03,
#        3.808170e+03, 1.288905e+03, 8.608000e+03, 2.709820e+03,
#        1.251043e+03, 1.046518e+03, 3.528090e+03, 2.299851e+03,
#        9.201900e+02, 4.223780e+03, 6.765000e+00, 1.135581e+03,
#        3.250870e+03, 4.595957e+03, 4.990000e+02, 2.515985e+03,
#        5.597700e+03, 1.426552e+03, 8.586030e+03, 2.943200e+03,
#        2.839150e+03, 8.504000e+03, 2.221847e+03, 5.121900e+02,
#        6.536400e+02, 6.599996e+03, 3.119300e+03, 5.144800e+03,
#        3.244980e+03, 2.184366e+03, 4.425380e+02, 7.754174e+03,
#        5.647130e+02, 4.732210e+03, 1.915609e+03, 4.048167e+03,
#        9.923840e+02, 6.723770e+03, 8.223200e+02, 2.076000e+03,
#        4.859200e+03, 3.858550e+03, 5.250000e+02, 5.059100e+03,
#        2.467680e+02, 4.321359e+03, 4.177350e+03, 3.358092e+03,
#        1.136183e+03, 5.011200e+03, 1.083180e+03, 3.752500e+03,
#        6.106280e+03, 4.393190e+02, 4.067349e+03, 1.650364e+03,
#        1.193500e+03, 1.136007e+03, 4.747360e+02, 2.366746e+03,
#        8.575700e+02, 3.621300e+03, 3.491210e+03, 2.656860e+03,
#        3.567710e+03, 1.849460e+02, 4.549119e+03, 6.644000e+03,
#        5.211100e+03, 1.140325e+03, 4.534500e+03, 5.990100e+03,
#        8.015000e+02, 4.636900e+03, 4.585000e+02, 7.155570e+03,
#        9.464760e+02, 5.059400e+03, 9.982940e+02, 4.721200e+03,
#        3.808360e+02, 1.320600e+03, 2.575800e+03, 4.900730e+02,
#        3.193770e+03, 5.988250e+03, 7.415450e+02, 1.021206e+03,
#        1.843755e+03, 3.061349e+03, 6.410000e+02, 3.259720e+03,
#        4.434240e+02, 2.234168e+03, 3.207759e+03, 1.440046e+03,
#        2.416894e+03, 4.369680e+03, 8.168000e+03, 1.204987e+03,
#        1.141536e+03, 6.035650e+03, 1.973960e+03, 1.013237e+03,
#        2.483860e+03, 5.025270e+02, 4.903280e+03, 1.360990e+03,
#        1.219920e+03, 4.075550e+03, 3.558850e+03, 9.160520e+02,
#        7.504500e+03, 1.207000e+03, 1.508729e+03, 8.346000e+03,
#        9.185040e+02, 1.169990e+03, 3.604210e+03, 2.111354e+03,
#        6.910000e+03, 1.212820e+03, 4.328340e+02, 7.544093e+03,
#        3.094978e+03, 2.140844e+03, 4.301220e+03, 9.069760e+02,
#        5.307800e+03, 2.546271e+03, 4.667460e+03, 5.157700e+03,
#        2.835167e+03, 3.210000e+02, 3.516100e+03, 9.436400e+02,
#        2.092528e+03, 7.799940e+02, 3.999240e+02, 2.066580e+03,
#        1.987340e+03, 5.707460e+03, 1.167695e+03, 4.515000e+03,
#        1.172500e+03, 4.685000e+02, 7.647000e+03, 8.841730e+02,
#        5.237130e+02, 3.241640e+03, 3.461810e+03, 5.323740e+02,
#        3.799600e+03, 4.863200e+03, 8.928630e+02, 1.146528e+03,
#        3.965200e+03, 4.936119e+03, 3.737780e+02, 1.752185e+03,
#        3.930000e+03, 4.990000e+02, 4.403000e+03, 3.994240e+02,
#        2.829450e+03, 5.141000e+02, 4.748185e+03, 3.976680e+02,
#        5.351000e+03, 4.236970e+03, 3.778440e+03, 3.085840e+03,
#        4.950000e+02, 7.416010e+02, 1.123500e+03, 5.303868e+03,
#        6.319420e+02, 2.681771e+03, 2.273640e+03, 5.116060e+02,
#        1.671548e+03, 4.985000e+02, 1.517228e+03, 4.519100e+03,
#        2.272750e+03, 1.785877e+03, 6.246590e+02, 2.718610e+03,
#        8.473200e+02, 7.395450e+02, 9.654210e+02, 3.990890e+02,
#        9.437460e+02, 2.511011e+03, 3.949480e+03, 2.289257e+03,
#        3.431000e+03, 4.775000e+02, 4.918650e+03, 5.133000e+03,
#        2.031530e+03, 7.162800e+02, 8.445560e+02])

# %% [markdown]
# # # Calculate the mean squared error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 696658.0971398292

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 834.660468178426

# %% [markdown]
# # R2 SCORE CALCULATION

# %%
# Calculate the R2 score
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.8864087285300852

# %% [markdown]
# # CALCULATION OF ACCURACY

# %%
 #Create a Random Forest regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the regressor
rf_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_regressor.predict(X_test)

# %%
# Calculate the accuracy (optional for regression)
accuracy = rf_regressor.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8897915047159676

# %% [markdown]
# # adjusted r2 score

# %%
# Calculate the adjusted R2 score
n = len(X_test)  # Number of samples
p = X_test.shape[1]  # Number of features
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print("Adjusted R2 Score:", adjusted_r2)
# Out:
# Adjusted R2 Score: 0.8356203234978637
